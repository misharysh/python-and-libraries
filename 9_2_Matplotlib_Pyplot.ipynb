# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.plot()
# Out:
# []

# %%
print 'y - values of list, x - indexes of elements'
plt.plot([1, 7, 3, 5, 11,1])
# Out:
# y - values of list, x - indexes of elements

# %%
plt.plot([1,5,10,15,20],[1,7,3,5,11])

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]

plt.plot(x,y, label='steel price')
plt.title('Chart price',fontsize=15)
plt.xlabel('Day',fontsize=12,color='blue')
plt.ylabel('Price',fontsize=12,color='blue')
plt.legend()
plt.grid(True)
plt.text(15,4,'grow up!')
# Out:
# Text(15,4,'grow up!')

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]
plt.plot(x,y,'--')

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]
line = plt.plot(x,y)
plt.setp(line, linestyle=':')
# Out:
# [None]

# %%
x = [1, 5, 10, 15, 20]
y1 = [1, 7, 3, 5, 11]
y2 = [i**1.2 + 1 for i in y1]
y3 = [i**1.2 + 1 for i in y2]
y4 = [i**1.2 + 1 for i in y3]

plt.plot(x,y1,'-',x,y2,'--',x,y3,'-.',x,y4,':')
# Out:
# [<matplotlib.lines.Line2D at 0x8e1b3c8>,
#  <matplotlib.lines.Line2D at 0x83c62e8>,
#  <matplotlib.lines.Line2D at 0x8e1bac8>,
#  <matplotlib.lines.Line2D at 0x8e1be48>]

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]

plt.plot(x,y,'ro')

# %%
x = [1, 5, 10, 15, 20]
y = [1, 7, 3, 5, 11]

plt.plot(x,y,'bx')

# %%
x = [1, 5, 10, 15, 20]
y1 = [1, 7, 3, 5, 11]
y2 = [i**1.2 + 1 for i in y1]
y3 = [i**1.2 + 1 for i in y2]
y4 = [i**1.2 + 1 for i in y3]

plt.figure(figsize=(12,7))
plt.subplot(2, 2, 1)
plt.plot(x, y1, '-')
plt.subplot(2, 2, 2)
plt.plot(x, y2, '--')
plt.subplot(2, 2, 3)
plt.plot(x, y3, '-.')
plt.subplot(2, 2, 4)
plt.plot(x, y4, ':')
